# %% [markdown]
# # Config Box

# %%
d1 = {"key":"val", "key1":"val1"}

# %%
d1['key1']
# Out:
# 'val1'

# %%
d1.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d1.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
type(d1)
# Out:
# dict

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %% [markdown]
# # Ensure Annotations

# %%
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x*y

# %%
get_product(x=2, y=3)
# Out:
# 6

# %%
get_product(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_product(x=2, y="3")
#
# File c:\Users\Om Mallick\.conda\envs\kidney-tensorflow\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002B2686E6830> does not match annotation type <class 'int'>

# %% [markdown]
# # Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1lUHj6HmdKg8IaIiY6WvcRI957BuH5DRa/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
print(file_id)
# Out:
# 1lUHj6HmdKg8IaIiY6WvcRI957BuH5DRa

# %%
prefix = 'https://drive.google.com/uc?/export=download'

# %%
gdown.download(prefix+file_id, "kidney-ct-scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1lUHj6HmdKg8IaIiY6WvcRI957BuH5DRa
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1lUHj6HmdKg8IaIiY6WvcRI957BuH5DRa&confirm=t&uuid=8750ba56-3ffc-460d-8256-be48a2ddfaa4
# To: d:\Major Project\Kidney-Disease-Classification-Tensorflow\research\kidney-ct-scan-data.zip
# 100%|██████████| 1.63G/1.63G [03:01<00:00, 8.96MB/s]
# 'kidney-ct-scan-data.zip'

# %% [markdown]
# # Model Visualisation

# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# %%
model = tf.keras.models.load_model("../artifacts/prepare_base_model/base_model.h5")
plot_model(model, to_file="../visualisations/base_model.png", show_shapes=True)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model = tf.keras.models.load_model("../artifacts/prepare_base_model/base_model_updated.h5")
plot_model(model, to_file="../visualisations/base_model_updated.png", show_shapes=True)

# %%
model = tf.keras.models.load_model("../artifacts/training/model.h5")
plot_model(model, to_file="../visualisations/trained_model.png", show_shapes=True)
